# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import requests
import pandas as pd
# from pandasgui import show
from alpha_vantage.alphavantage import AlphaVantage
from alpha_vantage.timeseries import TimeSeries
from bs4 import BeautifulSoup
import time
import numpy as np

def display_all(df):
    with pd.option_context("display.max_rows", 100000, "display.max_columns", 100000): 
        display(df)

# ///////////////////////////////////////////////////////////
# FUNCTIONS FOR ALPHA VANTAGE
# ///////////////////////////////////////////////////////////
TIME_SERIES_INTRADAY = 'TIME_SERIES_INTRADAY'
TIME_SERIES_INTRADAY_EXTENDED = 'TIME_SERIES_INTRADAY_EXTENDED'
TIME_SERIES_DAILY = 'TIME_SERIES_DAILY'
TIME_SERIES_DAILY_ADJUSTED = 'TIME_SERIES_DAILY_ADJUSTED'
TIME_SERIES_WEEKLY = 'TIME_SERIES_WEEKLY'
TIME_SERIES_WEEKLY_ADJUSTED = 'TIME_SERIES_WEEKLY_ADJUSTED'
TIME_SERIES_MONTHLY = 'TIME_SERIES_MONTHLY'
TIME_SERIES_MONTHLY_ADJUSTED = 'TIME_SERIES_MONTHLY_ADJUSTED'
GLOBAL_QUOTE = 'GLOBAL_QUOTE'
SYMBOL_SEARCH = 'SYMBOL_SEARCH'
OVERVIEW = 'OVERVIEW'
EARNINGS = 'EARNINGS'
INCOME_STATEMENT = 'INCOME_STATEMENT'
BALANCE_SHEET = 'BALANCE_SHEET'
CASH_FLOW = 'CASH_FLOW'
LISTING_STATUS = 'LISTING_STATUS'
EARNINGS_CALENDAR = 'EARNINGS_CALENDAR'
IPO_CALENDAR = 'IPO_CALENDAR'
CURRENCY_EXCHANGE_RATE = 'CURRENCY_EXCHANGE_RATE'
FX_INTRADAY = 'FX_INTRADAY'
FX_DAILY = 'FX_DAILY'
FX_WEEKLY = 'FX_WEEKLY'
FX_MONTHLY = 'FX_MONTHLY'
CURRENCY_EXCHANGE_RATE = 'CURRENCY_EXCHANGE_RATE'
CRYPTO_RATING = 'CRYPTO_RATING'
CRYPTO_INTRADAY = 'CRYPTO_INTRADAY'
DIGITAL_CURRENCY_DAILY = 'DIGITAL_CURRENCY_DAILY'
DIGITAL_CURRENCY_WEEKLY = 'DIGITAL_CURRENCY_WEEKLY'
DIGITAL_CURRENCY_MONTHLY = 'DIGITAL_CURRENCY_MONTHLY'

# ///////////////////////////////////////////////////////////
# TIME SERIES FOR STOCK DATA
# ///////////////////////////////////////////////////////////
ONEMIN = 'Time Series (1min)'
FIVEMIN = 'Time Series (5min)'
FIVETEENMIN = 'Time Series (15min)'
THIRTYMIN = 'Time Series (30min)'
HOUR = 'Time Series (60min)'
FIVEMIN = 'Time Series (5min)'
DAILY = 'Time Series (Daily)' 
WEEKLY = 'Weekly Time Series'
WEEKLY_ADJ = 'Weekly Adjusted Time Series'
MONTLY = 'Monthly Time Series'
MONTLY_ADJ = 'Monthly Adjusted Time Series'
# /////////////////////////////////////////////////////////
# query fundamental stock data of selected type ///////////
# /////////////////////////////////////////////////////////
def query_fundamental_data(func, symbol, apikey, outputsize='full', datatype='json'):
    data = {
        "function": func,
        "symbol": symbol,
        "outputsize": outputsize, # (full) and (compact) are accepted
        "datatype": datatype,
        "apikey": apikey
    }
    return requests.get("https://www.alphavantage.co/query", data).json()

def get_fundamental_dataframe(json):
    df = pd.DataFrame(json['annualReports'])
    df.set_index('fiscalDateEnding', inplace=True)
    return df

# FOR EARNINGS
def get_fundamental_dataframe1(json):
    df = pd.DataFrame(json['annualEarnings'])
    df.set_index('fiscalDateEnding', inplace=True)
    return df

#For Overview
def get_fundamental_dataframe2(json):
    df = pd.DataFrame(json, index=[1])
#     df.set_index(inplace=True)
    return df

def query_timeseries_data(func, symbol, apikey, outputsize='full', datatype='json'):
    data = {
        "function": func,
        "symbol": symbol,
        "outputsize": outputsize, # (full) and (compact) are accepted
        "datatype": datatype,
        "apikey": apikey
    }
    return requests.get("https://www.alphavantage.co/query", data).json()

def get_timeseries_dataframe(json, type):
    df = pd.DataFrame.from_dict(json[type], orient= 'index')
    df.index =  pd.to_datetime(df.index, format='%Y-%m-%d')
    
    df = df.rename(columns={ '1. open': 'Open', '2. high': 'High', '3. low': 'Low', '4. close': 'Close', '5. volume': 'Volume'})
    df = df.astype({'Open': 'float64', 'High': 'float64', 'Low': 'float64','Close': 'float64','Volume': 'float64',})
    df = df[[ 'Open', 'High', 'Low', 'Close', 'Volume']]
    return df

def get_data(stock, apikey):
#     import time

    response_json = query_fundamental_data(INCOME_STATEMENT, stock, apikey)
    INCOME_DATA = get_fundamental_dataframe(response_json)
    time.sleep(12)

    response_json = query_fundamental_data(BALANCE_SHEET, stock, apikey)
    BALANCE_DATA = get_fundamental_dataframe(response_json)
    time.sleep(12)

    response_json = query_fundamental_data(CASH_FLOW, stock, apikey)
    CASHFLOW_DATA = get_fundamental_dataframe(response_json)
    time.sleep(12)

    response_json = query_fundamental_data(EARNINGS, stock, apikey)
    EARNINGS_DATA = get_fundamental_dataframe1(response_json)
    time.sleep(12)

    response_json = query_fundamental_data(OVERVIEW, stock, apikey)
    OVERVIEW_DATA = get_fundamental_dataframe2(response_json)
    time.sleep(12)

    response_json = query_timeseries_data(TIME_SERIES_DAILY, stock, apikey)
    STOCKPRICE_DATA = get_timeseries_dataframe(response_json, DAILY)
    time.sleep(12)
    
    return INCOME_DATA,BALANCE_DATA,CASHFLOW_DATA,OVERVIEW_DATA,EARNINGS_DATA,STOCKPRICE_DATA
# response_json1,response_json2,response_json3,response_json4
# ,INCOME_DATA,BALANCE_DATA,CASHFLOW_DATA,EARNINGS_DATA,OVERVIEW_DATA

# %%
# Final 
def extractdata(stock,EarningorRevenue):
    # EarningorRevenue = [0] => Earning Estimate
    # EarningorRevenue = [1] => Revenue Estimate
    headers = {'User-Agent': 'Mozilla/5.0'}

    url = f"https://finance.yahoo.com/quote/{stock}/analysis?p={stock}"

    r = requests.get(url, headers=headers)
    # print(r.text)

    soup = BeautifulSoup(r.text, 'html.parser')
    # print(soup.prettify())
    Estimate_Table = soup.find_all("table", attrs={"class": "W(100%) M(0) BdB Bdc($seperatorColor) Mb(25px)"})
    table_thead = Estimate_Table[EarningorRevenue].thead.find_all("th")
    table_body = Estimate_Table[EarningorRevenue].find("tbody")

    headingitem = []
    table_data = []
    for i in table_thead:
    #     print(i.text)
        headingitem.append(i.text)
    for body in table_body:
        row_list = []
        for row in body:
            for item in row:
                row_list.append(item.text)        
        table_data.append(row_list)
    df = pd.DataFrame(table_data, columns = [headingitem])
    return df

# %%
def findcolnamematch(df,nameincluded):
#     nameincluded = 'income'
    cols=[]
    for i in df.columns.to_list():
        x = i.lower()
        if nameincluded in x:
            cols.append(i)
    return cols
# cols = findcolnamematch(IBC,'shares')
# IBC[cols]

# %%
def changeMoneytoNumbers(df,targetRow,colnum = 3):
    m = {'K': 3, 'M': 6, 'B': 9, 'T': 12}
    col = Revenue_Estimate.columns.to_list()[colnum]
    firstcol = df.columns.to_list()[0]
    df = df[df[firstcol] == targetRow]
    df[col] = [int(float(i[:-1]) * 10 ** m[i[-1]]) for i in df[col]]
    return(df)

# %%
def totalrevenueExtension(df,rownum):
    df['totalRevenue'].iloc[rownum] = ( df['totalRevenue'].iloc[rownum+1]*(100 +  df['totalRevenue_Growth_Rate_Mean'].iloc[rownum+1]))/100
    return df

# %%
def obtaindata(stock):
    headers = {'User-Agent': 'Mozilla/5.0'}
    
    #######################################
    # beta and market cap
    url_beta_marketCap = f'https://finance.yahoo.com/quote/{stock}?p={stock}'
    r_beta_marketCap = requests.get(url_beta_marketCap, headers=headers)
    soup_beta_marketCap = BeautifulSoup(r_beta_marketCap.text, 'html.parser')
    table = soup_beta_marketCap.find("table", attrs={"class": "W(100%) M(0) Bdcl(c)"})
    dataitem = table.tbody.find_all("tr")
    emptylist = []
    for i in dataitem[:2]:
        for j in i:
            emptylist.append(j.text) 
    marketcap = emptylist[1]
    beta = emptylist[3]
    
    ####################################################
    # To get bond 
    url_bond = f'https://finance.yahoo.com/bonds'
    r_bond = requests.get(url_bond, headers=headers)
    soup_bond = BeautifulSoup(r_bond.text, 'html.parser')
    table_bond = soup_bond.find("table", attrs={"class": "W(100%)"})
    treasurybond = []
    for j in table_bond.tbody.find_all("tr")[2]:
        treasurybond.append(j.text)
    bondvalue = treasurybond[2]
    
    return stock, marketcap,beta,bondvalue

# %% [markdown]
# # Final

# %%
# Final

stocks = ['MSFT']
API = ['53K56OJAX5T2DQJZ']
for x,y in zip(stocks,API):
    print(x,y)
    INCOME_DATA,BALANCE_DATA,CASHFLOW_DATA,OVERVIEW_DATA,EARNINGS_DATA,STOCKPRICE_DATA = get_data(x,y)

    BALANCE_DATA = BALANCE_DATA.drop(['reportedCurrency'], axis = 1)
    CASHFLOW_DATA = CASHFLOW_DATA.drop(['reportedCurrency','netIncome'], axis = 1)

    # Define percentage change formula for EARNING data
    EARNINGS_DATA = EARNINGS_DATA.apply(pd.to_numeric)
    EARNINGS_DATA['shifted_EPS'] = EARNINGS_DATA.reportedEPS.shift(-1, axis = 0)
    EARNINGS_DATA['EPS_Growth_Rate']= 100*((EARNINGS_DATA['reportedEPS'] - EARNINGS_DATA['shifted_EPS'])/ abs(EARNINGS_DATA['shifted_EPS']))

    EARNINGS_DATA[['EPS_Growth_Avg_Perc']] = EARNINGS_DATA[:6]['EPS_Growth_Rate'].mean()
    IBC = pd.merge(pd.merge(pd.merge(INCOME_DATA,BALANCE_DATA,on='fiscalDateEnding')
                            ,CASHFLOW_DATA,on='fiscalDateEnding')
                   ,EARNINGS_DATA,on='fiscalDateEnding')
    IBC = IBC.reset_index(0).reset_index(drop=True)
    IBC.replace('None', value=0, inplace=True)

    # # To replace change type to int after the column of 'reportedcurrency'
    index_no = IBC.columns.get_loc('reportedCurrency')
    index_no_starting = index_no+1
    IBC.iloc[:,index_no_starting:] = IBC.iloc[:,index_no_starting:].apply(pd.to_numeric)


    IBC['TotalDebt_FOR_DERatio'] = IBC['shortTermDebt']+IBC['longTermDebt']
    IBC['D/E Ratio'] = IBC['TotalDebt_FOR_DERatio']/IBC['totalShareholderEquity']

    IBC1 = IBC.copy()
    IBC1= pd.concat([OVERVIEW_DATA.reset_index(drop=True),IBC1.iloc[:1,:]], axis=1)
    IBC1['EntryPrice'] = IBC1['EPS_Growth_Avg_Perc'] * float(IBC1['EPS'])



    price = STOCKPRICE_DATA.iloc[:1,:].reset_index(drop=True)    
    IBC1 = pd.concat([IBC1,price], axis=1)

    IBC1['new_EntryPrice'] = [-x if y <0 else x for x,y in zip(IBC1['EntryPrice'],IBC1['EPS_Growth_Avg_Perc'])]
    
    # To obtain Analyst Predicted Revenue
    Revenue_Estimate = extractdata(x,1)
    targetRow = 'Avg. Estimate'

    Revenue_Estimate = changeMoneytoNumbers(Revenue_Estimate,targetRow,colnum = 3)
    Revenue_Estimate = changeMoneytoNumbers(Revenue_Estimate,targetRow,colnum = 4)
    analystval = Revenue_Estimate.iloc[:,-2:].values.tolist()[0]
    analystval[0], analystval[1] = analystval[1], analystval[0]
    
    IBC_DCF = IBC.copy()

    col = ['fiscalDateEnding','totalRevenue','netIncome','operatingCashflow','capitalExpenditures','interestAndDebtExpense','currentLongTermDebt','currentDebt',
       'longTermDebtNoncurrent','incomeBeforeTax','incomeTaxExpense','commonStockSharesOutstanding']
    IBC_DCF1 = IBC_DCF[col]
    IBC_DCF1['FreeCashFlowToEquity'] = IBC_DCF1['operatingCashflow'] - IBC_DCF1['capitalExpenditures']
    IBC_DCF1['FCFE/NetIncome(100%)'] = (IBC_DCF1['FreeCashFlowToEquity'] / IBC_DCF1['netIncome'])*100
    IBC_DCF1['Lowest_FCFE/NetIncome(100%)'] = IBC_DCF1['FCFE/NetIncome(100%)'].min()

    #create 2 years of blank data
    listofna = (len(IBC_DCF1.columns)-1)*[0]
    date = ['2025-01-22','2024-01-22','2023-01-22','2022-01-22']
    row=[]
    for i in date:
        onedate = []
        onedate.append(i)
        for j in listofna:
            onedate.append(j)
        row.append(onedate)

    # putting blank row into the df    
    colss = IBC_DCF1.columns.to_list()
    newrow = pd.DataFrame(row,columns = colss).reset_index(drop=True)
    IBC_DCF1 = pd.concat([newrow, IBC_DCF1], ignore_index=True, axis=0)

    # Replace the analyst avg rating into the df
    IBC_DCF1.iloc[2:4,1] = analystval
    
    IBC_DCF2 = IBC_DCF1.copy()
    IBC_DCF2['shifted_revenue'] = IBC_DCF2.totalRevenue.shift(-1, axis = 0)
    IBC_DCF2['totalRevenue_Growth_Rate(100%)']= 100*((IBC_DCF2['totalRevenue'] - IBC_DCF2['shifted_revenue'])/ abs(IBC_DCF2['shifted_revenue']))
    IBC_DCF2['totalRevenue_Growth_Rate(100%)'][1] = 0
    IBC_DCF2['totalRevenue_Growth_Rate_Mean'] = IBC_DCF2['totalRevenue_Growth_Rate(100%)'].mean()
    # IBC_DCF2['totalRevenue'].iloc[1] = ( IBC_DCF2['totalRevenue'].iloc[2]*(100 +  IBC_DCF2['totalRevenue_Growth_Rate_Mean'].iloc[2]))/100
    IBC_DCF2 = totalrevenueExtension(IBC_DCF2,1)
    IBC_DCF2 = totalrevenueExtension(IBC_DCF2,0)
    IBC_DCF2['NetIncomeMargin'] = IBC_DCF2['netIncome'] / IBC_DCF2['totalRevenue']
    IBC_DCF2['netIncome'].iloc[:4] = IBC_DCF2['totalRevenue'].iloc[:4] * IBC_DCF2[IBC_DCF2['NetIncomeMargin']>0]['NetIncomeMargin'].mean()
    IBC_DCF2['FreeCashFlowToEquity'].iloc[:4] = IBC_DCF2['netIncome'].iloc[:4]* (IBC_DCF2[IBC_DCF2['FCFE/NetIncome(100%)']>0]['FCFE/NetIncome(100%)'].min()/100)

    marketcap_beta_bond = obtaindata(x)

    rd = (IBC_DCF2['interestAndDebtExpense'][4]/(IBC_DCF2['currentLongTermDebt'][4]+IBC_DCF2['longTermDebtNoncurrent'][4]))*100
    if np.isnan(rd) ==True:
        rd = 1
    t = IBC_DCF2['incomeTaxExpense'][4]/IBC_DCF2['incomeBeforeTax'][4]

    # Market Cap
    marketcap = marketcap_beta_bond[1]
    m = {'K': 3, 'M': 6, 'B': 9, 'T': 12}
    marketcap = int(float(marketcap[:-1]) * 10 ** m[marketcap[-1]])
    totaldebt = IBC_DCF2['longTermDebtNoncurrent'][4]+IBC_DCF2['currentDebt'][4]
    total_Totaldebt_Marketcap = marketcap+totaldebt
    totaldebtRatio = totaldebt/total_Totaldebt_Marketcap*100
    marketcapRatio = marketcap/total_Totaldebt_Marketcap*100

    # All these are in percentage
    Rm = 10
    B = float(marketcap_beta_bond[2])
    rf = float(marketcap_beta_bond[3])
    re = rf+B*(Rm-rf)

    #WACC
    # wd = totaldebtratio
    # we = marketcapratio
    # WACC = wdrd(1-t) + were
    WACC = ((totaldebtRatio*rd*(1-t)) +(marketcapRatio*re))/100
    #PerpectualGrowth in %
    PerpectualGrowth = 2.5
    g = PerpectualGrowth/100
    r = WACC / 100
    sharesOutstanding = IBC_DCF2['commonStockSharesOutstanding']
    TerminalValue = (IBC_DCF2['FreeCashFlowToEquity'][0]*(1+g))/(r - g)

    discountfactorPower = []
    for i in range(4,0,-1):
    #     print(i)
        discountfactorPower.append((r+1)**i)
    IBC_DCF2['DiscountFactor'] = 0
    IBC_DCF2.loc[:3,'DiscountFactor'] = discountfactorPower
    IBC_DCF2['PVofFCF'] = 0
    IBC_DCF2.loc[:3,'PVofFCF'] = IBC_DCF2.loc[:3,'FreeCashFlowToEquity'] * IBC_DCF2.loc[:3,'DiscountFactor']
    PVofFCF_TerminalValue = TerminalValue * IBC_DCF2['DiscountFactor'][0]
    TodaysValue = PVofFCF_TerminalValue + IBC_DCF2['PVofFCF'][:4].sum()
    DCF_Stockprice = TodaysValue / IBC_DCF2['commonStockSharesOutstanding'][4]
    
    # What we want
    MichaelMethodValuation_Price = IBC1['new_EntryPrice'][0]
    
    DCF_Stockprice
# Out:
# MSFT 53K56OJAX5T2DQJZ
# C:\Users\sweet\AppData\Local\Temp/ipykernel_18448/1203267060.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = [int(float(i[:-1]) * 10 ** m[i[-1]]) for i in df[col]]
# C:\Users\sweet\AppData\Local\Temp/ipykernel_18448/3191591697.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF1['FreeCashFlowToEquity'] = IBC_DCF1['operatingCashflow'] - IBC_DCF1['capitalExpenditures']
# C:\Users\sweet\AppData\Local\Temp/ipykernel_18448/3191591697.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF1['FCFE/NetIncome(100%)'] = (IBC_DCF1['FreeCashFlowToEquity'] / IBC_DCF1['netIncome'])*100
# C:\Users\sweet\AppData\Local\Temp/ipykernel_18448/3191591697.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF1['Lowest_FCFE/NetIncome(100%)'] = IBC_DCF1['FCFE/NetIncome(100%)'].min()
# C:\Users\sweet\AppData\Local\Temp/ipykernel_18448/3191591697.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF2['totalRevenue_Growth_Rate(100%)'][1] = 0

# %% [markdown]
# # Testing for multiple stock

# %%
# Every 83 stocks change 1 api for 500 stocks
APIs = [
#         'GYX11ISSPTSUX78K',
#         'LYKZ99FFKIROA5CD',
        'TCQ580R24NR326XY',
        'W73KWACZE3ZXBDHV',
        'CKGAJT5WBGB6ZO4R',
        'XM7WRAS9NGUK7K1D',
        '53K56OJAX5T2DQJZ'
]
# GYX11ISSPTSUX78K
# BHUMOY6ID7RODFGB
# stockeg = stocks['Ticker'][:7]
# 500stocks * 6 API call = 3000 api calls [1 api = 500 calls per day]
# Every 83 stocks change 1 api for 500 stocks

apitouse = []
for i in APIs:
    for j in range(80):
        apitouse.append(i)
apitouse
# Out:
# ['TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'TCQ580R24NR326XY',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'W73KWACZE3ZXBDHV',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'CKGAJT5WBGB6ZO4R',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  'XM7WRAS9NGUK7K1D',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ',
#  '53K56OJAX5T2DQJZ']

# %%
# stocks = ['MSFT','AAPL','SAM']
# API = apitouse

stocks = ['MSFT']
API = ['53K56OJAX5T2DQJZ']

# %%
from ast import literal_eval
your_lists = (literal_eval(s) for s in open('listofStockBondBeta.txt'))
wantedlisthere = []
for i in your_lists:
    for j in i:
        wantedlisthere.append(j[0]) 
#         print(j[0])

# %%
wantedlisthere
# Out:
# ['A',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABMD',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AFL',
#  'AIG',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'ANET',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APTV',
#  'ARE',
#  'ATO',
#  'ATVI',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXP',
#  'AZO',
#  'BA',
#  'BAC',
#  'BAX',
#  'BBY',
#  'BDX',
#  'BEN',
#  'BIIB',
#  'BIO',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLL',
#  'BMY',
#  'BR',
#  'BSX',
#  'BWA',
#  'BXP',
#  'C',
#  'CAH',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
#  'CCI',
#  'CCL',
#  'CDNS',
#  'CDW',
#  'CE',
#  'CERN',
#  'CF',
#  'CFG',
#  'CHD',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CINF',
#  'CL',
#  'CLX',
#  'CMA',
#  'CMCSA',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMS',
#  'CNC',
#  'CNP',
#  'COF',
#  'COO',
#  'COP',
#  'COST',
#  'COTY',
#  'CPB',
#  'CPRT',
#  'CRM',
#  'CSCO',
#  'CSX',
#  'CTAS',
#  'CTSH',
#  'CTVA',
#  'CTXS',
#  'CVS',
#  'CVX',
#  'D',
#  'DAL',
#  'DD',
#  'DE',
#  'DFS',
#  'DG',
#  'DGX',
#  'DHI',
#  'DHR',
#  'DIS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DLR',
#  'DLTR',
#  'DOV',
#  'DOW',
#  'DPZ',
#  'DRE',
#  'DRI',
#  'DTE',
#  'DUK',
#  'DVA',
#  'DVN',
#  'DXC',
#  'DXCM',
#  'EA',
#  'EBAY',
#  'ECL',
#  'ED',
#  'EFX',
#  'EIX',
#  'EL',
#  'EMN',
#  'EMR',
#  'EOG',
#  'EQIX',
#  'EQR',
#  'ES',
#  'ESS',
#  'ETN',
#  'ETR',
#  'EVRG',
#  'EW',
#  'EXC',
#  'EXPD',
#  'EXPE',
#  'EXR',
#  'F',
#  'FANG',
#  'FAST',
#  'FB',
#  'FBHS',
#  'FCX',
#  'FDX',
#  'FE',
#  'FFIV',
#  'FIS',
#  'FISV',
#  'FITB',
#  'FLS',
#  'FOX',
#  'FOXA',
#  'FRC',
#  'FRT',
#  'FTI',
#  'FTNT',
#  'FTV',
#  'GD',
#  'GE',
#  'GILD',
#  'GIS',
#  'GL',
#  'GLW',
#  'GM',
#  'GOOG',
#  'GOOGL',
#  'GPC',
#  'GPN',
#  'GPS',
#  'GRMN',
#  'GS',
#  'GWW',
#  'HAL',
#  'HAS',
#  'HBAN',
#  'HBI',
#  'HCA',
#  'HD',
#  'HES',
#  'HFC',
#  'HIG',
#  'HII',
#  'HLT',
#  'HOLX',
#  'HON',
#  'HPE',
#  'HPQ',
#  'HRB',
#  'HRL',
#  'HSIC',
#  'HST',
#  'HSY',
#  'HUM',
#  'HWM',
#  'IBM',
#  'ICE',
#  'IEX',
#  'IFF',
#  'ILMN',
#  'INCY',
#  'INFO',
#  'INTC',
#  'INTU',
#  'IP',
#  'IPG',
#  'IPGP',
#  'IQV',
#  'IR',
#  'IRM',
#  'ISRG',
#  'IT',
#  'ITW',
#  'IVZ',
#  'J',
#  'JBHT',
#  'JCI',
#  'JKHY',
#  'JNJ',
#  'JNPR',
#  'JPM',
#  'K',
#  'KEY',
#  'KEYS',
#  'KHC',
#  'KIM',
#  'KLAC',
#  'KMB',
#  'KMI',
#  'KMX',
#  'KO',
#  'KR',
#  'KSS',
#  'L',
#  'LDOS',
#  'LEG',
#  'LEN',
#  'LH',
#  'LHX',
#  'LIN',
#  'LKQ',
#  'LLY',
#  'LMT',
#  'LNT',
#  'LOW',
#  'LRCX',
#  'LUV',
#  'LW',
#  'LYB',
#  'LYV',
#  'MA',
#  'MAA',
#  'MAR',
#  'MAS',
#  'MCD',
#  'MCHP',
#  'MCK',
#  'MCO',
#  'MDLZ',
#  'MDT',
#  'MET',
#  'MGM',
#  'MHK',
#  'MKC',
#  'MKTX',
#  'MLM',
#  'MMC',
#  'MMM',
#  'MNST',
#  'MO',
#  'MOS',
#  'MPC',
#  'MRO',
#  'MS',
#  'MSCI',
#  'MSFT',
#  'MSI',
#  'MTB',
#  'MTD',
#  'MU',
#  'NCLH',
#  'NDAQ',
#  'NEE',
#  'NEM',
#  'NFLX',
#  'NI',
#  'NKE',
#  'NLOK',
#  'NLSN',
#  'NOC',
#  'NOV',
#  'NOW',
#  'NRG',
#  'NSC',
#  'NTAP',
#  'NTRS',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NWL',
#  'NWS',
#  'NWSA',
#  'O',
#  'ODFL',
#  'OKE',
#  'OMC',
#  'ORCL',
#  'ORLY',
#  'OXY',
#  'PAYC',
#  'PAYX',
#  'PBCT',
#  'PCAR',
#  'PEAK',
#  'PEG',
#  'PEP',
#  'PFE',
#  'PFG',
#  'PG',
#  'PGR',
#  'PH',
#  'PHM',
#  'PKG',
#  'PLD',
#  'PM',
#  'PNC',
#  'PNR',
#  'PNW',
#  'PPG',
#  'PPL',
#  'PRGO',
#  'PRU',
#  'PSA',
#  'PSX',
#  'PVH',
#  'PWR',
#  'PXD',
#  'PYPL',
#  'QCOM',
#  'QRVO',
#  'RCL',
#  'RE',
#  'REG',
#  'REGN',
#  'RF',
#  'RHI',
#  'RJF',
#  'RL',
#  'RMD',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RSG',
#  'RTX',
#  'SBAC',
#  'SCHW',
#  'SEE',
#  'SHW',
#  'SIVB',
#  'SJM',
#  'SLB',
#  'SLG',
#  'SNA',
#  'SNPS',
#  'SO',
#  'SPG',
#  'SPGI',
#  'SRE',
#  'STE',
#  'STT',
#  'STX',
#  'STZ',
#  'SWK',
#  'SWKS',
#  'SYF',
#  'SYK',
#  'SYY',
#  'T',
#  'TAP',
#  'TDG',
#  'TDY',
#  'TEL',
#  'TFC',
#  'TFX',
#  'TGT',
#  'TJX',
#  'TMO',
#  'TMUS',
#  'TPR',
#  'TROW',
#  'TRV',
#  'TSCO',
#  'TSN',
#  'TT',
#  'TTWO',
#  'TWTR',
#  'TXN',
#  'TXT',
#  'TYL',
#  'UA',
#  'UAA',
#  'UAL',
#  'UDR',
#  'UHS',
#  'ULTA',
#  'UNH',
#  'UNM',
#  'UNP',
#  'UPS',
#  'URI',
#  'USB',
#  'VFC',
#  'VIAC',
#  'VLO',
#  'VMC',
#  'VNO',
#  'VRSK',
#  'VRSN',
#  'VRTX',
#  'VTR',
#  'VZ',
#  'WAB',
#  'WAT',
#  'WBA',
#  'WDC',
#  'WEC',
#  'WELL',
#  'WFC',
#  'WHR',
#  'WLTW',
#  'WM',
#  'WMB',
#  'WMT',
#  'WRB',
#  'WRK',
#  'WST',
#  'WU',
#  'WY',
#  'WYNN',
#  'XEL',
#  'XLNX',
#  'XOM',
#  'XRAY',
#  'XRX',
#  'XYL',
#  'YUM',
#  'ZBH',
#  'ZBRA',
#  'ZION',
#  'ZTS']

# %%
stocks = wantedlisthere[80:150]
stocks
# Out:
# ['CERN',
#  'CF',
#  'CFG',
#  'CHD',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CINF',
#  'CL',
#  'CLX',
#  'CMA',
#  'CMCSA',
#  'CME',
#  'CMG',
#  'CMI',
#  'CMS',
#  'CNC',
#  'CNP',
#  'COF',
#  'COO',
#  'COP',
#  'COST',
#  'COTY',
#  'CPB',
#  'CPRT',
#  'CRM',
#  'CSCO',
#  'CSX',
#  'CTAS',
#  'CTSH',
#  'CTVA',
#  'CTXS',
#  'CVS',
#  'CVX',
#  'D',
#  'DAL',
#  'DD',
#  'DE',
#  'DFS',
#  'DG',
#  'DGX',
#  'DHI',
#  'DHR',
#  'DIS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DLR',
#  'DLTR',
#  'DOV',
#  'DOW',
#  'DPZ',
#  'DRE',
#  'DRI',
#  'DTE',
#  'DUK',
#  'DVA',
#  'DVN',
#  'DXC',
#  'DXCM',
#  'EA',
#  'EBAY',
#  'ECL',
#  'ED',
#  'EFX',
#  'EIX',
#  'EL',
#  'EMN',
#  'EMR',
#  'EOG']

# %%
stocks
for x,y in zip(stocks,API):
    print(x,y)
# Out:
# AMGN TCQ580R24NR326XY
# AMP TCQ580R24NR326XY
# AMT TCQ580R24NR326XY
# AMZN TCQ580R24NR326XY
# ANET TCQ580R24NR326XY
# ANSS TCQ580R24NR326XY
# ANTM TCQ580R24NR326XY
# AON TCQ580R24NR326XY
# AOS TCQ580R24NR326XY
# APA TCQ580R24NR326XY
# APD TCQ580R24NR326XY
# APH TCQ580R24NR326XY
# APTV TCQ580R24NR326XY
# ARE TCQ580R24NR326XY
# ATO TCQ580R24NR326XY
# ATVI TCQ580R24NR326XY
# AVB TCQ580R24NR326XY
# AVGO TCQ580R24NR326XY
# AVY TCQ580R24NR326XY
# AWK TCQ580R24NR326XY
# AXP TCQ580R24NR326XY
# AZO TCQ580R24NR326XY
# BA TCQ580R24NR326XY
# BAC TCQ580R24NR326XY
# BAX TCQ580R24NR326XY
# BBY TCQ580R24NR326XY
# BDX TCQ580R24NR326XY
# BEN TCQ580R24NR326XY
# BIIB TCQ580R24NR326XY
# BIO TCQ580R24NR326XY
# BK TCQ580R24NR326XY
# BKNG TCQ580R24NR326XY
# BKR TCQ580R24NR326XY
# BLL TCQ580R24NR326XY
# BMY TCQ580R24NR326XY
# BR TCQ580R24NR326XY
# BSX TCQ580R24NR326XY
# BWA TCQ580R24NR326XY
# BXP TCQ580R24NR326XY
# C TCQ580R24NR326XY
# CAH TCQ580R24NR326XY
# CAT TCQ580R24NR326XY
# CB TCQ580R24NR326XY
# CBOE TCQ580R24NR326XY
# CBRE TCQ580R24NR326XY
# CCI TCQ580R24NR326XY
# CCL TCQ580R24NR326XY
# CDNS TCQ580R24NR326XY
# CDW TCQ580R24NR326XY
# CE TCQ580R24NR326XY

# %%
# Final2
# dfstock = pd.Dataframe(columns = cols)
API = apitouse
fullwantedlist = []
nooblist = []

for x,y in zip(stocks,API):
    print(x,y)
    try:
        INCOME_DATA,BALANCE_DATA,CASHFLOW_DATA,OVERVIEW_DATA,EARNINGS_DATA,STOCKPRICE_DATA = get_data(x,y)

        BALANCE_DATA = BALANCE_DATA.drop(['reportedCurrency'], axis = 1)
        CASHFLOW_DATA = CASHFLOW_DATA.drop(['reportedCurrency','netIncome'], axis = 1)

        # Define percentage change formula for EARNING data
        EARNINGS_DATA = EARNINGS_DATA.apply(pd.to_numeric)
        EARNINGS_DATA['shifted_EPS'] = EARNINGS_DATA.reportedEPS.shift(-1, axis = 0)
        EARNINGS_DATA['EPS_Growth_Rate']= 100*((EARNINGS_DATA['reportedEPS'] - EARNINGS_DATA['shifted_EPS'])/ abs(EARNINGS_DATA['shifted_EPS']))
        EARNINGS_DATA[['EPS_Growth_Avg_Perc']] = EARNINGS_DATA[:6]['EPS_Growth_Rate'].mean()
        IBC = pd.merge(pd.merge(pd.merge(INCOME_DATA,BALANCE_DATA,on='fiscalDateEnding')
                                ,CASHFLOW_DATA,on='fiscalDateEnding')
                       ,EARNINGS_DATA,on='fiscalDateEnding')
        IBC = IBC.reset_index(0).reset_index(drop=True)
        IBC.replace('None', value=0, inplace=True)

        # # To replace change type to int after the column of 'reportedcurrency'
        index_no = IBC.columns.get_loc('reportedCurrency')
        index_no_starting = index_no+1
        IBC.iloc[:,index_no_starting:] = IBC.iloc[:,index_no_starting:].apply(pd.to_numeric)


        IBC['TotalDebt_FOR_DERatio'] = IBC['shortTermDebt']+IBC['longTermDebt']
        IBC['D/E Ratio'] = IBC['TotalDebt_FOR_DERatio']/IBC['totalShareholderEquity']

        IBC1 = IBC.copy()
        IBC1= pd.concat([OVERVIEW_DATA.reset_index(drop=True),IBC1.iloc[:1,:]], axis=1)
        IBC1['EntryPrice'] = IBC1['EPS_Growth_Avg_Perc'] * float(IBC1['EPS'])



        price = STOCKPRICE_DATA.iloc[:1,:].reset_index(drop=True)    
        IBC1 = pd.concat([IBC1,price], axis=1)

        IBC1['new_EntryPrice'] = [-x if y <0 else x for x,y in zip(IBC1['EntryPrice'],IBC1['EPS_Growth_Avg_Perc'])]
################################################################################################################
#DCF Method

        # To obtain Analyst Predicted Revenue
        Revenue_Estimate = extractdata(x,1)
        targetRow = 'Avg. Estimate'

        Revenue_Estimate = changeMoneytoNumbers(Revenue_Estimate,targetRow,colnum = 3)
        Revenue_Estimate = changeMoneytoNumbers(Revenue_Estimate,targetRow,colnum = 4)
        analystval = Revenue_Estimate.iloc[:,-2:].values.tolist()[0]
        analystval[0], analystval[1] = analystval[1], analystval[0]

        IBC_DCF = IBC.copy()

        col = ['fiscalDateEnding','totalRevenue','netIncome','operatingCashflow','capitalExpenditures','interestAndDebtExpense','currentLongTermDebt','currentDebt',
           'longTermDebtNoncurrent','incomeBeforeTax','incomeTaxExpense','commonStockSharesOutstanding']
        IBC_DCF1 = IBC_DCF[col]
        IBC_DCF1['FreeCashFlowToEquity'] = IBC_DCF1['operatingCashflow'] - IBC_DCF1['capitalExpenditures']
        IBC_DCF1['FCFE/NetIncome(100%)'] = (IBC_DCF1['FreeCashFlowToEquity'] / IBC_DCF1['netIncome'])*100
        IBC_DCF1['Lowest_FCFE/NetIncome(100%)'] = IBC_DCF1['FCFE/NetIncome(100%)'].min()

        #create 2 years of blank data
        listofna = (len(IBC_DCF1.columns)-1)*[0]
        date = ['2025-01-22','2024-01-22','2023-01-22','2022-01-22']
        row=[]
        for i in date:
            onedate = []
            onedate.append(i)
            for j in listofna:
                onedate.append(j)
            row.append(onedate)

        # putting blank row into the df    
        colss = IBC_DCF1.columns.to_list()
        newrow = pd.DataFrame(row,columns = colss).reset_index(drop=True)
        IBC_DCF1 = pd.concat([newrow, IBC_DCF1], ignore_index=True, axis=0)

        # Replace the analyst avg rating into the df
        IBC_DCF1.iloc[2:4,1] = analystval

        IBC_DCF2 = IBC_DCF1.copy()
        IBC_DCF2['shifted_revenue'] = IBC_DCF2.totalRevenue.shift(-1, axis = 0)
        IBC_DCF2['totalRevenue_Growth_Rate(100%)']= 100*((IBC_DCF2['totalRevenue'] - IBC_DCF2['shifted_revenue'])/ abs(IBC_DCF2['shifted_revenue']))
        IBC_DCF2['totalRevenue_Growth_Rate(100%)'][1] = 0
        IBC_DCF2['totalRevenue_Growth_Rate_Mean'] = IBC_DCF2['totalRevenue_Growth_Rate(100%)'].mean()
        # IBC_DCF2['totalRevenue'].iloc[1] = ( IBC_DCF2['totalRevenue'].iloc[2]*(100 +  IBC_DCF2['totalRevenue_Growth_Rate_Mean'].iloc[2]))/100
        IBC_DCF2 = totalrevenueExtension(IBC_DCF2,1)
        IBC_DCF2 = totalrevenueExtension(IBC_DCF2,0)
        IBC_DCF2['NetIncomeMargin'] = IBC_DCF2['netIncome'] / IBC_DCF2['totalRevenue']
        IBC_DCF2['netIncome'].iloc[:4] = IBC_DCF2['totalRevenue'].iloc[:4] * IBC_DCF2[IBC_DCF2['NetIncomeMargin']>0]['NetIncomeMargin'].mean()
        IBC_DCF2['FreeCashFlowToEquity'].iloc[:4] = IBC_DCF2['netIncome'].iloc[:4]* (IBC_DCF2[IBC_DCF2['FCFE/NetIncome(100%)']>0]['FCFE/NetIncome(100%)'].min()/100)

        marketcap_beta_bond = obtaindata(x)

        rd = (IBC_DCF2['interestAndDebtExpense'][4]/(IBC_DCF2['currentLongTermDebt'][4]+IBC_DCF2['longTermDebtNoncurrent'][4]))*100
        if np.isnan(rd) ==True:
            rd = 1
        t = IBC_DCF2['incomeTaxExpense'][4]/IBC_DCF2['incomeBeforeTax'][4]

        # Market Cap
        marketcap = marketcap_beta_bond[1]
        m = {'K': 3, 'M': 6, 'B': 9, 'T': 12}
        marketcap = int(float(marketcap[:-1]) * 10 ** m[marketcap[-1]])
        totaldebt = IBC_DCF2['longTermDebtNoncurrent'][4]+IBC_DCF2['currentDebt'][4]
        total_Totaldebt_Marketcap = marketcap+totaldebt
        totaldebtRatio = totaldebt/total_Totaldebt_Marketcap*100
        marketcapRatio = marketcap/total_Totaldebt_Marketcap*100

        # All these are in percentage
        Rm = 10
        B = float(marketcap_beta_bond[2])
        rf = float(marketcap_beta_bond[3])
        re = rf+B*(Rm-rf)

        #WACC
        # wd = totaldebtratio
        # we = marketcapratio
        # WACC = wdrd(1-t) + were
        WACC = ((totaldebtRatio*rd*(1-t)) +(marketcapRatio*re))/100
        #PerpectualGrowth in %
        PerpectualGrowth = 2.5
        g = PerpectualGrowth/100
        r = WACC / 100
        sharesOutstanding = IBC_DCF2['commonStockSharesOutstanding']
        TerminalValue = (IBC_DCF2['FreeCashFlowToEquity'][0]*(1+g))/(r - g)

        discountfactorPower = []
        for i in range(4,0,-1):
        #     print(i)
            discountfactorPower.append((r+1)**i)
        IBC_DCF2['DiscountFactor'] = 0
        IBC_DCF2.loc[:3,'DiscountFactor'] = discountfactorPower
        IBC_DCF2['PVofFCF'] = 0
        IBC_DCF2.loc[:3,'PVofFCF'] = IBC_DCF2.loc[:3,'FreeCashFlowToEquity'] * IBC_DCF2.loc[:3,'DiscountFactor']
        PVofFCF_TerminalValue = TerminalValue * IBC_DCF2['DiscountFactor'][0]
        TodaysValue = PVofFCF_TerminalValue + IBC_DCF2['PVofFCF'][:4].sum()
        DCF_Stockprice = TodaysValue / IBC_DCF2['commonStockSharesOutstanding'][4]
        
#######################################################################

        # What we want
        currentstockprice = STOCKPRICE_DATA['Close'][0]
        MichaelMethodValuation_Price = IBC1['new_EntryPrice'][0]
        sector = OVERVIEW_DATA[['Sector']].iloc[0,0]
        industry = OVERVIEW_DATA[['Industry']].iloc[0,0]
        
        # Remember to add in the column name when some column added into wantedlist
        wantedlist = [x,sector, industry, DCF_Stockprice,MichaelMethodValuation_Price,currentstockprice]
        fullwantedlist.append(wantedlist)
    except:
        nooblist.append(x)
        continue

colsssssss = ['stock','sector','industry','DCF_Stockprice','MichaelMethodValuation_Price','currentstockprice']
WantedDf = pd.DataFrame(fullwantedlist, columns=colsssssss)
# Out:
# CERN TCQ580R24NR326XY
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/1203267060.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = [int(float(i[:-1]) * 10 ** m[i[-1]]) for i in df[col]]
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/1758643715.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF1['FreeCashFlowToEquity'] = IBC_DCF1['operatingCashflow'] - IBC_DCF1['capitalExpenditures']
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/1758643715.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF1['FCFE/NetIncome(100%)'] = (IBC_DCF1['FreeCashFlowToEquity'] / IBC_DCF1['netIncome'])*100
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/1758643715.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF1['Lowest_FCFE/NetIncome(100%)'] = IBC_DCF1['FCFE/NetIncome(100%)'].min()
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/1758643715.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF2['totalRevenue_Growth_Rate(100%)'][1] = 0
# C:\Users\sweet\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# CF TCQ580R24NR326XY
# CFG TCQ580R24NR326XY
# CHD TCQ580R24NR326XY
# CHRW TCQ580R24NR326XY
# CHTR TCQ580R24NR326XY
# CI TCQ580R24NR326XY
# CINF TCQ580R24NR326XY
# CL TCQ580R24NR326XY
# CLX TCQ580R24NR326XY
# CMA TCQ580R24NR326XY
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/1758643715.py:99: RuntimeWarning: divide by zero encountered in longlong_scalars
#   rd = (IBC_DCF2['interestAndDebtExpense'][4]/(IBC_DCF2['currentLongTermDebt'][4]+IBC_DCF2['longTermDebtNoncurrent'][4]))*100
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/1758643715.py:123: RuntimeWarning: invalid value encountered in double_scalars
#   WACC = ((totaldebtRatio*rd*(1-t)) +(marketcapRatio*re))/100
# CMCSA TCQ580R24NR326XY
# CME TCQ580R24NR326XY
# CMG TCQ580R24NR326XY
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/1758643715.py:99: RuntimeWarning: invalid value encountered in longlong_scalars
#   rd = (IBC_DCF2['interestAndDebtExpense'][4]/(IBC_DCF2['currentLongTermDebt'][4]+IBC_DCF2['longTermDebtNoncurrent'][4]))*100
# CMI TCQ580R24NR326XY
# CMS TCQ580R24NR326XY
# CNC TCQ580R24NR326XY
# CNP TCQ580R24NR326XY
# COF TCQ580R24NR326XY
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/1758643715.py:139: RuntimeWarning: invalid value encountered in double_scalars
#   PVofFCF_TerminalValue = TerminalValue * IBC_DCF2['DiscountFactor'][0]
# COO TCQ580R24NR326XY
# COP TCQ580R24NR326XY
# COST TCQ580R24NR326XY
# COTY TCQ580R24NR326XY
# CPB TCQ580R24NR326XY
# CPRT TCQ580R24NR326XY
# CRM TCQ580R24NR326XY
# CSCO TCQ580R24NR326XY
# CSX TCQ580R24NR326XY
# CTAS TCQ580R24NR326XY
# CTSH TCQ580R24NR326XY
# CTVA TCQ580R24NR326XY
# CTXS TCQ580R24NR326XY
# CVS TCQ580R24NR326XY
# CVX TCQ580R24NR326XY
# D TCQ580R24NR326XY
# DAL TCQ580R24NR326XY
# DD TCQ580R24NR326XY
# DE TCQ580R24NR326XY
# DFS TCQ580R24NR326XY
# DG TCQ580R24NR326XY
# DGX TCQ580R24NR326XY
# DHI TCQ580R24NR326XY
# DHR TCQ580R24NR326XY
# DIS TCQ580R24NR326XY
# DISCA TCQ580R24NR326XY
# DISCK TCQ580R24NR326XY
# DISH TCQ580R24NR326XY
# DLR TCQ580R24NR326XY
# DLTR TCQ580R24NR326XY
# DOV TCQ580R24NR326XY
# DOW TCQ580R24NR326XY
# DPZ TCQ580R24NR326XY
# DRE TCQ580R24NR326XY
# DRI TCQ580R24NR326XY
# DTE TCQ580R24NR326XY
# DUK TCQ580R24NR326XY
# DVA TCQ580R24NR326XY
# DVN TCQ580R24NR326XY
# DXC TCQ580R24NR326XY
# DXCM TCQ580R24NR326XY
# EA TCQ580R24NR326XY
# EBAY TCQ580R24NR326XY
# ECL TCQ580R24NR326XY
# ED TCQ580R24NR326XY
# EFX TCQ580R24NR326XY
# EIX TCQ580R24NR326XY
# EL TCQ580R24NR326XY
# EMN TCQ580R24NR326XY
# EMR TCQ580R24NR326XY
# EOG TCQ580R24NR326XY

# %%
nooblist
# Out:
# ['COST', 'CPB', 'DLTR', 'EOG']

# %%
WantedDf
# Out:
#    stock                   sector  \
# 0   CERN               TECHNOLOGY
# 1     CF            LIFE SCIENCES
# 2    CFG                  FINANCE
# 3    CHD            LIFE SCIENCES
# 4   CHRW  ENERGY & TRANSPORTATION
# ..   ...                      ...
# 61   EFX         TRADE & SERVICES
# 62   EIX  ENERGY & TRANSPORTATION
# 63    EL            LIFE SCIENCES
# 64   EMN            LIFE SCIENCES
# 65   EMR            MANUFACTURING
#
#                                              industry  DCF_Stockprice  \
# 0         SERVICES-COMPUTER INTEGRATED SYSTEMS DESIGN       59.380266
# 1                              AGRICULTURAL CHEMICALS      239.608663
# 2                              STATE COMMERCIAL BANKS       73.143951
# 3   SOAP, DETERGENTS, CLEANG PREPARATIONS, PERFUME...      166.397916
# 4    ARRANGEMENT OF TRANSPORTATION OF FREIGHT & CARGO      152.755385
# ..                                                ...             ...
# 61  SERVICES-CONSUMER CREDIT REPORTING, COLLECTION...       35.313854
# 62                                  ELECTRIC SERVICES      351.840738
# 63    PERFUMES, COSMETICS & OTHER TOILET PREPARATIONS      170.148143
# 64  PLASTIC MATERIALS, SYNTH RESINS & NONVULCAN EL...       76.476441
# 65  ELECTRONIC & OTHER ELECTRICAL EQUIPMENT (NO CO...       90.152897
#
#     MichaelMethodValuation_Price  currentstockprice
# 0                       4.385673              92.21
# 1                      94.105076              66.44
# 2                      95.042533              56.35
# 3                      23.506948             104.22
# 4                      34.964501             108.29
# ..                           ...                ...
# 61                     29.720224             249.50
# 62                      4.203130              63.75
# 63                     27.705801             322.05
# 64                      0.637447             127.54
# 65                     40.333627              97.47
#
# [66 rows x 6 columns]

# %%
list3 = WantedDf.copy()
list3
# Out:
#    stock                   sector  \
# 0   CERN               TECHNOLOGY
# 1     CF            LIFE SCIENCES
# 2    CFG                  FINANCE
# 3    CHD            LIFE SCIENCES
# 4   CHRW  ENERGY & TRANSPORTATION
# ..   ...                      ...
# 61   EFX         TRADE & SERVICES
# 62   EIX  ENERGY & TRANSPORTATION
# 63    EL            LIFE SCIENCES
# 64   EMN            LIFE SCIENCES
# 65   EMR            MANUFACTURING
#
#                                              industry  DCF_Stockprice  \
# 0         SERVICES-COMPUTER INTEGRATED SYSTEMS DESIGN       59.380266
# 1                              AGRICULTURAL CHEMICALS      239.608663
# 2                              STATE COMMERCIAL BANKS       73.143951
# 3   SOAP, DETERGENTS, CLEANG PREPARATIONS, PERFUME...      166.397916
# 4    ARRANGEMENT OF TRANSPORTATION OF FREIGHT & CARGO      152.755385
# ..                                                ...             ...
# 61  SERVICES-CONSUMER CREDIT REPORTING, COLLECTION...       35.313854
# 62                                  ELECTRIC SERVICES      351.840738
# 63    PERFUMES, COSMETICS & OTHER TOILET PREPARATIONS      170.148143
# 64  PLASTIC MATERIALS, SYNTH RESINS & NONVULCAN EL...       76.476441
# 65  ELECTRONIC & OTHER ELECTRICAL EQUIPMENT (NO CO...       90.152897
#
#     MichaelMethodValuation_Price  currentstockprice
# 0                       4.385673              92.21
# 1                      94.105076              66.44
# 2                      95.042533              56.35
# 3                      23.506948             104.22
# 4                      34.964501             108.29
# ..                           ...                ...
# 61                     29.720224             249.50
# 62                      4.203130              63.75
# 63                     27.705801             322.05
# 64                      0.637447             127.54
# 65                     40.333627              97.47
#
# [66 rows x 6 columns]

# %%
list1
# Out:
#    stock                   sector  \
# 0      A            LIFE SCIENCES
# 1    AAL  ENERGY & TRANSPORTATION
# 2    AAP         TRADE & SERVICES
# 3   AAPL               TECHNOLOGY
# 4   ABBV            LIFE SCIENCES
# 5    ABC         TRADE & SERVICES
# 6   ABMD            LIFE SCIENCES
# 7    ABT            LIFE SCIENCES
# 8    ACN         TRADE & SERVICES
# 9   ADBE               TECHNOLOGY
# 10   ADI            MANUFACTURING
# 11   ADM            MANUFACTURING
# 12   ADP               TECHNOLOGY
# 13  ADSK               TECHNOLOGY
# 14   AEE  ENERGY & TRANSPORTATION
# 15   AEP  ENERGY & TRANSPORTATION
# 16   AFL                  FINANCE
# 17   AIG                  FINANCE
# 18   AIZ                  FINANCE
# 19   AJG                  FINANCE
# 20  AKAM         TRADE & SERVICES
# 21   ALB            LIFE SCIENCES
# 22  ALGN            LIFE SCIENCES
# 23   ALK  ENERGY & TRANSPORTATION
# 24   ALL                  FINANCE
# 25  ALLE         TRADE & SERVICES
# 26  AMAT            MANUFACTURING
# 27  AMCR            MANUFACTURING
# 28   AMD            MANUFACTURING
# 29   AME            LIFE SCIENCES
#
#                                              industry  DCF_Stockprice  \
# 0   INSTRUMENTS FOR MEAS & TESTING OF ELECTRICITY ...       84.398455
# 1                       AIR TRANSPORTATION, SCHEDULED       40.893985
# 2                    RETAIL-AUTO & HOME SUPPLY STORES      101.950101
# 3                                ELECTRONIC COMPUTERS      144.884362
# 4                         PHARMACEUTICAL PREPARATIONS      331.430867
# 5   WHOLESALE-DRUGS, PROPRIETARIES & DRUGGISTS' SU...      310.092164
# 6          SURGICAL & MEDICAL INSTRUMENTS & APPARATUS      135.422935
# 7                         PHARMACEUTICAL PREPARATIONS       95.623770
# 8                     SERVICES-BUSINESS SERVICES, NEC      317.521056
# 9                       SERVICES-PREPACKAGED SOFTWARE             NaN
# 10                   SEMICONDUCTORS & RELATED DEVICES      435.640708
# 11                                        FATS & OILS             NaN
# 12    SERVICES-COMPUTER PROCESSING & DATA PREPARATION      200.509984
# 13                      SERVICES-PREPACKAGED SOFTWARE       10.618090
# 14                 ELECTRIC & OTHER SERVICES COMBINED       15.857027
# 15                                  ELECTRIC SERVICES      474.131081
# 16                        ACCIDENT & HEALTH INSURANCE             NaN
# 17                  FIRE, MARINE & CASUALTY INSURANCE      102.459522
# 18                            INSURANCE CARRIERS, NEC             NaN
# 19                INSURANCE AGENTS, BROKERS & SERVICE      146.322285
# 20                    SERVICES-BUSINESS SERVICES, NEC      130.217036
# 21  PLASTIC MATERIALS, SYNTH RESINS & NONVULCAN EL...      107.148646
# 22  ORTHOPEDIC, PROSTHETIC & SURGICAL APPLIANCES &...      149.083064
# 23                      AIR TRANSPORTATION, SCHEDULED       60.091843
# 24                  FIRE, MARINE & CASUALTY INSURANCE             NaN
# 25   SERVICES-DETECTIVE, GUARD & ARMORED CAR SERVICES      107.551714
# 26                   SEMICONDUCTORS & RELATED DEVICES      159.548189
# 27             MISCELLANEOUS MANUFACTURING INDUSTRIES       11.066002
# 28                   SEMICONDUCTORS & RELATED DEVICES       16.800564
# 29  INDUSTRIAL INSTRUMENTS FOR MEASUREMENT, DISPLA...      118.608288
#
#     MichaelMethodValuation_Price  currentstockprice
# 0                      66.383254             144.68
# 1                    -423.435453              18.49
# 2                      57.262060             239.60
# 3                      20.859465             173.07
# 4                      62.954759             135.87
# 5                      58.039067             136.20
# 6                      83.735966             301.22
# 7                      42.399426             128.16
# 8                      24.732591             353.36
# 9                     355.851011             520.60
# 10                     51.669751             172.00
# 11                     35.564409              71.55
# 12                      6.223149             228.75
# 13                    362.018994             259.10
# 14                     18.590950              88.09
# 15                      3.217203              90.98
# 16                      2.181848              64.06
# 17                   2909.421566              61.91
# 18                    174.391421             154.89
# 19                     47.792614             157.70
# 20                     38.906560             112.62
# 21                      3.680707             233.67
# 22                    296.661079             524.63
# 23                     -0.058140              55.79
# 24                    168.947739             124.08
# 25                     30.116739             124.46
# 26                    256.467252             167.00
# 27                     15.671921              12.37
# 28                    352.456272             136.88
# 29                     26.284901             141.54

# %%
mergeddf12 = pd.concat([list1,list2], ignore_index=True)
mergeddf12
# Out:
#    stock                      sector  \
# 0      A               LIFE SCIENCES
# 1    AAL     ENERGY & TRANSPORTATION
# 2    AAP            TRADE & SERVICES
# 3   AAPL                  TECHNOLOGY
# 4   ABBV               LIFE SCIENCES
# ..   ...                         ...
# 73   CCI  REAL ESTATE & CONSTRUCTION
# 74   CCL     ENERGY & TRANSPORTATION
# 75  CDNS                  TECHNOLOGY
# 76   CDW            TRADE & SERVICES
# 77    CE               LIFE SCIENCES
#
#                                              industry  DCF_Stockprice  \
# 0   INSTRUMENTS FOR MEAS & TESTING OF ELECTRICITY ...       84.398455
# 1                       AIR TRANSPORTATION, SCHEDULED       40.893985
# 2                    RETAIL-AUTO & HOME SUPPLY STORES      101.950101
# 3                                ELECTRONIC COMPUTERS      144.884362
# 4                         PHARMACEUTICAL PREPARATIONS      331.430867
# ..                                                ...             ...
# 73                      REAL ESTATE INVESTMENT TRUSTS       60.832668
# 74                               WATER TRANSPORTATION        1.868507
# 75                      SERVICES-PREPACKAGED SOFTWARE       44.353265
# 76                 RETAIL-CATALOG & MAIL-ORDER HOUSES      204.345725
# 77  PLASTIC MATERIAL, SYNTH RESIN/RUBBER, CELLULOS...      198.232509
#
#     MichaelMethodValuation_Price  currentstockprice
# 0                      66.383254             144.68
# 1                    -423.435453              18.49
# 2                      57.262060             239.60
# 3                      20.859465             173.07
# 4                      62.954759             135.87
# ..                           ...                ...
# 73                      2.259849             184.15
# 74                   -295.439894              22.95
# 75                     38.834859             161.75
# 76                     93.287327             191.64
# 77                    453.466834             173.53
#
# [78 rows x 6 columns]

# %%
 mergeddf123 = pd.concat([mergeddf12,list3], ignore_index=True)
mergeddf123
# Out:
#     stock                   sector  \
# 0       A            LIFE SCIENCES
# 1     AAL  ENERGY & TRANSPORTATION
# 2     AAP         TRADE & SERVICES
# 3    AAPL               TECHNOLOGY
# 4    ABBV            LIFE SCIENCES
# ..    ...                      ...
# 139   EFX         TRADE & SERVICES
# 140   EIX  ENERGY & TRANSPORTATION
# 141    EL            LIFE SCIENCES
# 142   EMN            LIFE SCIENCES
# 143   EMR            MANUFACTURING
#
#                                               industry  DCF_Stockprice  \
# 0    INSTRUMENTS FOR MEAS & TESTING OF ELECTRICITY ...       84.398455
# 1                        AIR TRANSPORTATION, SCHEDULED       40.893985
# 2                     RETAIL-AUTO & HOME SUPPLY STORES      101.950101
# 3                                 ELECTRONIC COMPUTERS      144.884362
# 4                          PHARMACEUTICAL PREPARATIONS      331.430867
# ..                                                 ...             ...
# 139  SERVICES-CONSUMER CREDIT REPORTING, COLLECTION...       35.313854
# 140                                  ELECTRIC SERVICES      351.840738
# 141    PERFUMES, COSMETICS & OTHER TOILET PREPARATIONS      170.148143
# 142  PLASTIC MATERIALS, SYNTH RESINS & NONVULCAN EL...       76.476441
# 143  ELECTRONIC & OTHER ELECTRICAL EQUIPMENT (NO CO...       90.152897
#
#      MichaelMethodValuation_Price  currentstockprice
# 0                       66.383254             144.68
# 1                     -423.435453              18.49
# 2                       57.262060             239.60
# 3                       20.859465             173.07
# 4                       62.954759             135.87
# ..                            ...                ...
# 139                     29.720224             249.50
# 140                      4.203130              63.75
# 141                     27.705801             322.05
# 142                      0.637447             127.54
# 143                     40.333627              97.47
#
# [144 rows x 6 columns]

# %%
mergeddf123.to_csv('mergeddf123.csv',index=False)

# %%
# mergeddf['A'] = [1 ]
mergeddf123['DCF_Stockprice_1'] = [1 if x >y else -1 for x,y in zip(mergeddf123['DCF_Stockprice'],mergeddf123['currentstockprice'])]
mergeddf123
# Out:
#     stock                   sector  \
# 0       A            LIFE SCIENCES
# 1     AAL  ENERGY & TRANSPORTATION
# 2     AAP         TRADE & SERVICES
# 3    AAPL               TECHNOLOGY
# 4    ABBV            LIFE SCIENCES
# ..    ...                      ...
# 139   EFX         TRADE & SERVICES
# 140   EIX  ENERGY & TRANSPORTATION
# 141    EL            LIFE SCIENCES
# 142   EMN            LIFE SCIENCES
# 143   EMR            MANUFACTURING
#
#                                               industry  DCF_Stockprice  \
# 0    INSTRUMENTS FOR MEAS & TESTING OF ELECTRICITY ...       84.398455
# 1                        AIR TRANSPORTATION, SCHEDULED       40.893985
# 2                     RETAIL-AUTO & HOME SUPPLY STORES      101.950101
# 3                                 ELECTRONIC COMPUTERS      144.884362
# 4                          PHARMACEUTICAL PREPARATIONS      331.430867
# ..                                                 ...             ...
# 139  SERVICES-CONSUMER CREDIT REPORTING, COLLECTION...       35.313854
# 140                                  ELECTRIC SERVICES      351.840738
# 141    PERFUMES, COSMETICS & OTHER TOILET PREPARATIONS      170.148143
# 142  PLASTIC MATERIALS, SYNTH RESINS & NONVULCAN EL...       76.476441
# 143  ELECTRONIC & OTHER ELECTRICAL EQUIPMENT (NO CO...       90.152897
#
#      MichaelMethodValuation_Price  currentstockprice  DCF_Stockprice_1
# 0                       66.383254             144.68                -1
# 1                     -423.435453              18.49                 1
# 2                       57.262060             239.60                -1
# 3                       20.859465             173.07                -1
# 4                       62.954759             135.87                 1
# ..                            ...                ...               ...
# 139                     29.720224             249.50                -1
# 140                      4.203130              63.75                 1
# 141                     27.705801             322.05                -1
# 142                      0.637447             127.54                -1
# 143                     40.333627              97.47                -1
#
# [144 rows x 7 columns]

# %%
mergeddf123['MichaelMethodValuation_Price_1'] = [1 if x >y else -1 for x,y in zip(mergeddf123['MichaelMethodValuation_Price'],mergeddf123['currentstockprice'])]
mergeddf123
# Out:
#     stock                   sector  \
# 0       A            LIFE SCIENCES
# 1     AAL  ENERGY & TRANSPORTATION
# 2     AAP         TRADE & SERVICES
# 3    AAPL               TECHNOLOGY
# 4    ABBV            LIFE SCIENCES
# ..    ...                      ...
# 139   EFX         TRADE & SERVICES
# 140   EIX  ENERGY & TRANSPORTATION
# 141    EL            LIFE SCIENCES
# 142   EMN            LIFE SCIENCES
# 143   EMR            MANUFACTURING
#
#                                               industry  DCF_Stockprice  \
# 0    INSTRUMENTS FOR MEAS & TESTING OF ELECTRICITY ...       84.398455
# 1                        AIR TRANSPORTATION, SCHEDULED       40.893985
# 2                     RETAIL-AUTO & HOME SUPPLY STORES      101.950101
# 3                                 ELECTRONIC COMPUTERS      144.884362
# 4                          PHARMACEUTICAL PREPARATIONS      331.430867
# ..                                                 ...             ...
# 139  SERVICES-CONSUMER CREDIT REPORTING, COLLECTION...       35.313854
# 140                                  ELECTRIC SERVICES      351.840738
# 141    PERFUMES, COSMETICS & OTHER TOILET PREPARATIONS      170.148143
# 142  PLASTIC MATERIALS, SYNTH RESINS & NONVULCAN EL...       76.476441
# 143  ELECTRONIC & OTHER ELECTRICAL EQUIPMENT (NO CO...       90.152897
#
#      MichaelMethodValuation_Price  currentstockprice  DCF_Stockprice_1  \
# 0                       66.383254             144.68                -1
# 1                     -423.435453              18.49                 1
# 2                       57.262060             239.60                -1
# 3                       20.859465             173.07                -1
# 4                       62.954759             135.87                 1
# ..                            ...                ...               ...
# 139                     29.720224             249.50                -1
# 140                      4.203130              63.75                 1
# 141                     27.705801             322.05                -1
# 142                      0.637447             127.54                -1
# 143                     40.333627              97.47                -1
#
#      MichaelMethodValuation_Price_1
# 0                                -1
# 1                                -1
# 2                                -1
# 3                                -1
# 4                                -1
# ..                              ...
# 139                              -1
# 140                              -1
# 141                              -1
# 142                              -1
# 143                              -1
#
# [144 rows x 8 columns]

# %%
mergeddf
# Out:
#    stock                      sector  \
# 0      A               LIFE SCIENCES
# 1    AAL     ENERGY & TRANSPORTATION
# 2    AAP            TRADE & SERVICES
# 3   AAPL                  TECHNOLOGY
# 4   ABBV               LIFE SCIENCES
# ..   ...                         ...
# 43   CCI  REAL ESTATE & CONSTRUCTION
# 44   CCL     ENERGY & TRANSPORTATION
# 45  CDNS                  TECHNOLOGY
# 46   CDW            TRADE & SERVICES
# 47    CE               LIFE SCIENCES
#
#                                              industry  DCF_Stockprice  \
# 0   INSTRUMENTS FOR MEAS & TESTING OF ELECTRICITY ...       84.398455
# 1                       AIR TRANSPORTATION, SCHEDULED       40.893985
# 2                    RETAIL-AUTO & HOME SUPPLY STORES      101.950101
# 3                                ELECTRONIC COMPUTERS      144.884362
# 4                         PHARMACEUTICAL PREPARATIONS      331.430867
# ..                                                ...             ...
# 43                      REAL ESTATE INVESTMENT TRUSTS       60.832668
# 44                               WATER TRANSPORTATION        1.868507
# 45                      SERVICES-PREPACKAGED SOFTWARE       44.353265
# 46                 RETAIL-CATALOG & MAIL-ORDER HOUSES      204.345725
# 47  PLASTIC MATERIAL, SYNTH RESIN/RUBBER, CELLULOS...      198.232509
#
#     MichaelMethodValuation_Price  currentstockprice  DCF_Stockprice_1  \
# 0                      66.383254             144.68                 1
# 1                    -423.435453              18.49                -1
# 2                      57.262060             239.60                 1
# 3                      20.859465             173.07                 1
# 4                      62.954759             135.87                -1
# ..                           ...                ...               ...
# 43                      2.259849             184.15                 1
# 44                   -295.439894              22.95                 1
# 45                     38.834859             161.75                 1
# 46                     93.287327             191.64                -1
# 47                    453.466834             173.53                -1
#
#     MichaelMethodValuation_Price_1
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 4                                1
# ..                             ...
# 43                               1
# 44                               1
# 45                               1
# 46                               1
# 47                              -1
#
# [78 rows x 8 columns]

# %%
mergeddf123[(mergeddf123['DCF_Stockprice_1']==1) & (mergeddf123['MichaelMethodValuation_Price_1']==1)]
# Out:
#      stock                   sector  \
# 17     AIG                  FINANCE
# 77      CE            LIFE SCIENCES
# 79      CF            LIFE SCIENCES
# 80     CFG                  FINANCE
# 84      CI                  FINANCE
# 113     DE               TECHNOLOGY
# 114    DFS                  FINANCE
# 116    DGX            LIFE SCIENCES
# 121  DISCK               TECHNOLOGY
# 125    DOW            LIFE SCIENCES
# 132    DVN  ENERGY & TRANSPORTATION
#
#                                               industry  DCF_Stockprice  \
# 17                   FIRE, MARINE & CASUALTY INSURANCE      102.459522
# 77   PLASTIC MATERIAL, SYNTH RESIN/RUBBER, CELLULOS...      198.232509
# 79                              AGRICULTURAL CHEMICALS      239.608663
# 80                              STATE COMMERCIAL BANKS       73.143951
# 84                    HOSPITAL & MEDICAL SERVICE PLANS     1279.890552
# 113                         FARM MACHINERY & EQUIPMENT      629.215111
# 114                       PERSONAL CREDIT INSTITUTIONS      514.952654
# 116                      SERVICES-MEDICAL LABORATORIES      219.618252
# 121              CABLE & OTHER PAY TELEVISION SERVICES      134.294784
# 125  PLASTIC MATERIALS, SYNTH RESINS & NONVULCAN EL...      237.357244
# 132                      CRUDE PETROLEUM & NATURAL GAS       94.771655
#
#      MichaelMethodValuation_Price  currentstockprice  DCF_Stockprice_1  \
# 17                    2909.421566              61.91                 1
# 77                     453.466834             173.53                 1
# 79                      94.105076              66.44                 1
# 80                      95.042533              56.35                 1
# 84                     287.734160             242.17                 1
# 113                    551.925644             379.56                 1
# 114                    738.512549             127.54                 1
# 116                    280.062782             142.30                 1
# 121                     80.298911              30.40                 1
# 125                    878.790604              60.74                 1
# 132                    640.266346              50.39                 1
#
#      MichaelMethodValuation_Price_1
# 17                                1
# 77                                1
# 79                                1
# 80                                1
# 84                                1
# 113                               1
# 114                               1
# 116                               1
# 121                               1
# 125                               1
# 132                               1

# %% [markdown]
# # Read betabond list

# %%
import json
with open('listofStockBondBeta.txt', 'r') as f:
    listofStockBondBeta = json.loads(f.read())

# %%
listofStockBondBeta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21204/2231920592.py in <module>
# ----> 1 listofStockBondBeta
#
# NameError: name 'listofStockBondBeta' is not defined

# %% [markdown]
# # Single Stock Inspection

# %%
stocks = ['SAM']
API = ['53K56OJAX5T2DQJZ']
for x,y in zip(stocks,API):
    print(x,y)
    INCOME_DATA,BALANCE_DATA,CASHFLOW_DATA,OVERVIEW_DATA,EARNINGS_DATA,STOCKPRICE_DATA = get_data(x,y)

    BALANCE_DATA = BALANCE_DATA.drop(['reportedCurrency'], axis = 1)
    CASHFLOW_DATA = CASHFLOW_DATA.drop(['reportedCurrency','netIncome'], axis = 1)

    # Define percentage change formula for EARNING data
    EARNINGS_DATA = EARNINGS_DATA.apply(pd.to_numeric)
    EARNINGS_DATA['shifted_EPS'] = EARNINGS_DATA.reportedEPS.shift(-1, axis = 0)
    EARNINGS_DATA['EPS_Growth_Rate']= 100*((EARNINGS_DATA['reportedEPS'] - EARNINGS_DATA['shifted_EPS'])/ abs(EARNINGS_DATA['shifted_EPS']))

    EARNINGS_DATA[['EPS_Growth_Avg_Perc']] = EARNINGS_DATA[:6]['EPS_Growth_Rate'].mean()
    IBC = pd.merge(pd.merge(pd.merge(INCOME_DATA,BALANCE_DATA,on='fiscalDateEnding')
                            ,CASHFLOW_DATA,on='fiscalDateEnding')
                   ,EARNINGS_DATA,on='fiscalDateEnding')
    IBC = IBC.reset_index(0).reset_index(drop=True)
    IBC.replace('None', value=0, inplace=True)

    # # To replace change type to int after the column of 'reportedcurrency'
    index_no = IBC.columns.get_loc('reportedCurrency')
    index_no_starting = index_no+1
    IBC.iloc[:,index_no_starting:] = IBC.iloc[:,index_no_starting:].apply(pd.to_numeric)


    IBC['TotalDebt_FOR_DERatio'] = IBC['shortTermDebt']+IBC['longTermDebt']
    IBC['D/E Ratio'] = IBC['TotalDebt_FOR_DERatio']/IBC['totalShareholderEquity']

    IBC1 = IBC.copy()
    IBC1= pd.concat([OVERVIEW_DATA.reset_index(drop=True),IBC1.iloc[:1,:]], axis=1)
    IBC1['EntryPrice'] = IBC1['EPS_Growth_Avg_Perc'] * float(IBC1['EPS'])



    price = STOCKPRICE_DATA.iloc[:1,:].reset_index(drop=True)    
    IBC1 = pd.concat([IBC1,price], axis=1)

    IBC1['new_EntryPrice'] = [-x if y <0 else x for x,y in zip(IBC1['EntryPrice'],IBC1['EPS_Growth_Avg_Perc'])]
    
    # To obtain Analyst Predicted Revenue
    Revenue_Estimate = extractdata(x,1)
    targetRow = 'Avg. Estimate'

    Revenue_Estimate = changeMoneytoNumbers(Revenue_Estimate,targetRow,colnum = 3)
    Revenue_Estimate = changeMoneytoNumbers(Revenue_Estimate,targetRow,colnum = 4)
    analystval = Revenue_Estimate.iloc[:,-2:].values.tolist()[0]
    analystval[0], analystval[1] = analystval[1], analystval[0]
    
    IBC_DCF = IBC.copy()

    col = ['fiscalDateEnding','totalRevenue','netIncome','operatingCashflow','capitalExpenditures','interestAndDebtExpense','currentLongTermDebt','currentDebt',
       'longTermDebtNoncurrent','incomeBeforeTax','incomeTaxExpense','commonStockSharesOutstanding']
    IBC_DCF1 = IBC_DCF[col]
    IBC_DCF1['FreeCashFlowToEquity'] = IBC_DCF1['operatingCashflow'] - IBC_DCF1['capitalExpenditures']
    IBC_DCF1['FCFE/NetIncome(100%)'] = (IBC_DCF1['FreeCashFlowToEquity'] / IBC_DCF1['netIncome'])*100
    IBC_DCF1['Lowest_FCFE/NetIncome(100%)'] = IBC_DCF1['FCFE/NetIncome(100%)'].min()

    #create 2 years of blank data
    listofna = (len(IBC_DCF1.columns)-1)*[0]
    date = ['2025-01-22','2024-01-22','2023-01-22','2022-01-22']
    row=[]
    for i in date:
        onedate = []
        onedate.append(i)
        for j in listofna:
            onedate.append(j)
        row.append(onedate)

    # putting blank row into the df    
    colss = IBC_DCF1.columns.to_list()
    newrow = pd.DataFrame(row,columns = colss).reset_index(drop=True)
    IBC_DCF1 = pd.concat([newrow, IBC_DCF1], ignore_index=True, axis=0)

    # Replace the analyst avg rating into the df
    IBC_DCF1.iloc[2:4,1] = analystval
    
    IBC_DCF2 = IBC_DCF1.copy()
    IBC_DCF2['shifted_revenue'] = IBC_DCF2.totalRevenue.shift(-1, axis = 0)
    IBC_DCF2['totalRevenue_Growth_Rate(100%)']= 100*((IBC_DCF2['totalRevenue'] - IBC_DCF2['shifted_revenue'])/ abs(IBC_DCF2['shifted_revenue']))
    IBC_DCF2['totalRevenue_Growth_Rate(100%)'][1] = 0
    IBC_DCF2['totalRevenue_Growth_Rate_Mean'] = IBC_DCF2['totalRevenue_Growth_Rate(100%)'].mean()
    # IBC_DCF2['totalRevenue'].iloc[1] = ( IBC_DCF2['totalRevenue'].iloc[2]*(100 +  IBC_DCF2['totalRevenue_Growth_Rate_Mean'].iloc[2]))/100
    IBC_DCF2 = totalrevenueExtension(IBC_DCF2,1)
    IBC_DCF2 = totalrevenueExtension(IBC_DCF2,0)
    IBC_DCF2['NetIncomeMargin'] = IBC_DCF2['netIncome'] / IBC_DCF2['totalRevenue']
    IBC_DCF2['netIncome'].iloc[:4] = IBC_DCF2['totalRevenue'].iloc[:4] * IBC_DCF2[IBC_DCF2['NetIncomeMargin']>0]['NetIncomeMargin'].mean()
    # if optimistic can change the min to mean function
    IBC_DCF2['FreeCashFlowToEquity'].iloc[:4] = IBC_DCF2['netIncome'].iloc[:4]* (IBC_DCF2[IBC_DCF2['FCFE/NetIncome(100%)']>0]['FCFE/NetIncome(100%)'].min()/100)

    marketcap_beta_bond = obtaindata(x)

    rd = (IBC_DCF2['interestAndDebtExpense'][4]/(IBC_DCF2['currentLongTermDebt'][4]+IBC_DCF2['longTermDebtNoncurrent'][4]))*100
    if np.isnan(rd) ==True:
        rd = 1
        
    t = IBC_DCF2['incomeTaxExpense'][4]/IBC_DCF2['incomeBeforeTax'][4]

    # Market Cap
    marketcap = marketcap_beta_bond[1]
    m = {'K': 3, 'M': 6, 'B': 9, 'T': 12}
    marketcap = int(float(marketcap[:-1]) * 10 ** m[marketcap[-1]])
    totaldebt = IBC_DCF2['longTermDebtNoncurrent'][4]+IBC_DCF2['currentDebt'][4]
    total_Totaldebt_Marketcap = marketcap+totaldebt
    totaldebtRatio = totaldebt/total_Totaldebt_Marketcap*100
    marketcapRatio = marketcap/total_Totaldebt_Marketcap*100

    # All these are in percentage
    Rm = 10
    B = float(marketcap_beta_bond[2])
    rf = float(marketcap_beta_bond[3])
    re = rf+B*(Rm-rf)

    #WACC
    # wd = totaldebtratio
    # we = marketcapratio
    # WACC = wdrd(1-t) + were
    WACC = ((totaldebtRatio*rd*(1-t)) +(marketcapRatio*re))/100
    #PerpectualGrowth in %
    PerpectualGrowth = 2.5
    g = PerpectualGrowth/100
    r = WACC / 100
    sharesOutstanding = IBC_DCF2['commonStockSharesOutstanding']
    TerminalValue = (IBC_DCF2['FreeCashFlowToEquity'][0]*(1+g))/(r - g)

    discountfactorPower = []
    for i in range(4,0,-1):
    #     print(i)
        discountfactorPower.append((r+1)**i)
    IBC_DCF2['DiscountFactor'] = 0
    IBC_DCF2.loc[:3,'DiscountFactor'] = discountfactorPower
    IBC_DCF2['PVofFCF'] = 0
    IBC_DCF2.loc[:3,'PVofFCF'] = IBC_DCF2.loc[:3,'FreeCashFlowToEquity'] * IBC_DCF2.loc[:3,'DiscountFactor']
    PVofFCF_TerminalValue = TerminalValue * IBC_DCF2['DiscountFactor'][0]
    TodaysValue = PVofFCF_TerminalValue + IBC_DCF2['PVofFCF'][:4].sum()
    DCF_Stockprice = TodaysValue / IBC_DCF2['commonStockSharesOutstanding'][4]
    
    # What we want
    MichaelMethodValuation_Price = IBC1['new_EntryPrice'][0]
    
    wantedlist = [x,DCF_Stockprice,MichaelMethodValuation_Price]
#     fullwantedlist.append(wantedlist)
# Out:
# SAM 53K56OJAX5T2DQJZ
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/1203267060.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = [int(float(i[:-1]) * 10 ** m[i[-1]]) for i in df[col]]
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/460112742.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF1['FreeCashFlowToEquity'] = IBC_DCF1['operatingCashflow'] - IBC_DCF1['capitalExpenditures']
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/460112742.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF1['FCFE/NetIncome(100%)'] = (IBC_DCF1['FreeCashFlowToEquity'] / IBC_DCF1['netIncome'])*100
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/460112742.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF1['Lowest_FCFE/NetIncome(100%)'] = IBC_DCF1['FCFE/NetIncome(100%)'].min()
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/460112742.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IBC_DCF2['totalRevenue_Growth_Rate(100%)'][1] = 0
# C:\Users\sweet\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\sweet\AppData\Local\Temp/ipykernel_21204/460112742.py:94: RuntimeWarning: invalid value encountered in longlong_scalars
#   rd = (IBC_DCF2['interestAndDebtExpense'][4]/(IBC_DCF2['currentLongTermDebt'][4]+IBC_DCF2['longTermDebtNoncurrent'][4]))*100

# %%
wantedlist
# Out:
# ['SAM', 480.43849537846677, 91.93330066073362]

# %%
df1 = OVERVIEW_DATA[['Sector','Industry']]
df2=df1.copy()
df2
# Out:
#           Sector        Industry
# 1  MANUFACTURING  MALT BEVERAGES

# %%
sector = OVERVIEW_DATA[['Sector']].iloc[0,0]
# sector
industry = OVERVIEW_DATA[['Industry']].iloc[0,0]
# industry
# Out:
# 'MANUFACTURING'

# %%
# Out:
# 'MALT BEVERAGES'

# %%
# df1.append(df2)
pd.concat([df1, df2], axis=1)
# Out:
#           Sector        Industry         Sector        Industry
# 1  MANUFACTURING  MALT BEVERAGES  MANUFACTURING  MALT BEVERAGES
